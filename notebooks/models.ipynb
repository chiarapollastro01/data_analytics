# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath('..'))
from src.animal_shelter import preprocess_shelter_data
from sklearn.ensemble import RandomForestClassifier

# %%
df_raw = pd.read_csv('../data/train.csv')
X, y, breed_map, color_map = preprocess_shelter_data(df_raw)
